# %%
#PROJECT 2- LEVEL-1
### Customer Segmentation Analysis
import pandas as pd
df=pd.read_csv("C:/Users/shiva/Documents/oasis/ifood_df.csv")
df
# Out:
#        Income  Kidhome  Teenhome  Recency  MntWines  MntFruits  \
# 0     58138.0        0         0       58       635         88
# 1     46344.0        1         1       38        11          1
# 2     71613.0        0         0       26       426         49
# 3     26646.0        1         0       26        11          4
# 4     58293.0        1         0       94       173         43
# ...       ...      ...       ...      ...       ...        ...
# 2200  61223.0        0         1       46       709         43
# 2201  64014.0        2         1       56       406          0
# 2202  56981.0        0         0       91       908         48
# 2203  69245.0        0         1        8       428         30
# 2204  52869.0        1         1       40        84          3
#
#       MntMeatProducts  MntFishProducts  MntSweetProducts  MntGoldProds  ...  \
# 0                 546              172                88            88  ...
# ...

# %%
print("First few rows of the dataset:")
print(df.head())


print("\nSummary of the dataset:")
print(df.info())


print("\nStatistical summary of the dataset:")
print(df.describe())

# Step 3: Clean the dataset

print("\nMissing values in each column:")
print(df.isnull().sum())


df['Income'] = df['Income'].fillna(df['Income'].mean())
# Out:
# First few rows of the dataset:
#     Income  Kidhome  Teenhome  Recency  MntWines  MntFruits  MntMeatProducts  \
# 0  58138.0        0         0       58       635         88              546
# 1  46344.0        1         1       38        11          1                6
# 2  71613.0        0         0       26       426         49              127
# 3  26646.0        1         0       26        11          4               20
# 4  58293.0        1         0       94       173         43              118
#
#    MntFishProducts  MntSweetProducts  MntGoldProds  ...  marital_Together  \
# 0              172                88            88  ...                 0
# 1                2                 1             6  ...                 0
# 2              111                21            42  ...                 1
# 3               10                 3             5  ...                 1
# 4               46                27            15  ...                 0
#
# ...

# %%
print("\nMissing values after cleaning:")
print(df.isnull().sum())
# Out:
# Missing values after cleaning:
# Income                  0
# Kidhome                 0
# Teenhome                0
# Recency                 0
# MntWines                0
# MntFruits               0
# MntMeatProducts         0
# MntFishProducts         0
# MntSweetProducts        0
# MntGoldProds            0
# NumDealsPurchases       0
# NumWebPurchases         0
# NumCatalogPurchases     0
# NumStorePurchases       0
# NumWebVisitsMonth       0
# AcceptedCmp3            0
# AcceptedCmp4            0
# AcceptedCmp5            0
# AcceptedCmp1            0
# AcceptedCmp2            0
# Complain                0
# Z_CostContact           0
# Z_Revenue               0
# Response                0
# Age                     0
# Customer_Days           0
# marital_Divorced        0
# marital_Married         0
# marital_Single          0
# marital_Together        0
# marital_Widow           0
# education_2n Cycle      0
# education_Basic         0
# education_Graduation    0
# ...

# %%
# Step 4: Calculate Descriptive Statistics
# Calculate average purchase value
average_purchase_value = df['MntTotal'].mean()
print(f"\nAverage purchase value: {average_purchase_value:.2f}")

# Calculate frequency of purchases per customer (based on number of accepted campaigns)
purchase_frequency = df['AcceptedCmpOverall']
print("\nPurchase frequency per customer (number of accepted campaigns):")
print(purchase_frequency.value_counts())
# Out:
# Average purchase value: 562.76
#
# Purchase frequency per customer (number of accepted campaigns):
# 0    1747
# 1     322
# 2      81
# 3      44
# 4      11
# Name: AcceptedCmpOverall, dtype: int64

# %%
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import seaborn as sns

# Select relevant features
features = ['Income', 'Kidhome', 'Teenhome', 'Recency', 'MntWines', 'MntFruits', 'MntMeatProducts',
            'MntFishProducts', 'MntSweetProducts', 'MntGoldProds', 'MntTotal']

# Normalize the features
scaler = StandardScaler()
df_scaled = scaler.fit_transform(df[features])

# Step 3: Apply K-means clustering
# Determine the optimal number of clusters using the elbow method
inertia = []
K = range(1, 11)
for k in K:
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(df_scaled)
    inertia.append(kmeans.inertia_)

# Plot the elbow method
plt.figure(figsize=(10, 6))
plt.plot(K, inertia, 'bo-')
plt.xlabel('Number of clusters')
plt.ylabel('Inertia')
plt.title('Elbow Method For Optimal k')
plt.show()

# Apply K-means with the optimal number of clusters (let's assume k=4 based on the elbow plot)
kmeans = KMeans(n_clusters=4, random_state=42)
df['Cluster'] = kmeans.fit_predict(df_scaled)

# Step 4: Visualize the customer segments
# Plot clusters
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='Income', y='MntTotal', hue='Cluster', palette='viridis')
plt.title('Customer Segments by Income and Total Spend')
plt.xlabel('Income')
plt.ylabel('Total Spend')
plt.legend(title='Cluster')
plt.show()


# Step 5: Analyze characteristics of each segment and provide insights
# Group by cluster and calculate mean values
cluster_summary = df.groupby('Cluster')[features].mean()
print("\nCluster Summary:")
print(cluster_summary)

# Add more analysis as needed
# Example: Distribution of 'Kidhome' and 'Teenhome' in each cluster
plt.figure(figsize=(10, 6))
sns.boxplot(data=df, x='Cluster', y='Kidhome', palette='viridis')
plt.title('Distribution of Kidhome in Each Cluster')
plt.xlabel('Cluster')
plt.ylabel('Kidhome')
plt.show()

plt.figure(figsize=(10, 6))
sns.boxplot(data=df, x='Cluster', y='Teenhome', palette='viridis')
plt.title('Distribution of Teenhome in Each Cluster')
plt.xlabel('Cluster')
plt.ylabel('Teenhome')
plt.show()
# Out:
# c:\Users\shiva\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\shiva\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\shiva\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# ...

# %%
# Step 6: Insights and Recommendations
for cluster in range(4):
    print(f"\nCluster {cluster} characteristics:")
    print(cluster_summary.loc[cluster])
    print(f"Number of customers: {len(df[df['Cluster'] == cluster])}")

    # Example insights
    if cluster_summary.loc[cluster]['Income'] > df['Income'].mean():
        print("This cluster has a higher than average income.")
    else:
        print("This cluster has a lower than average income.")
    
    if cluster_summary.loc[cluster]['MntTotal'] > df['MntTotal'].mean():
        print("This cluster spends more than the average.")
    else:
        print("This cluster spends less than the average.")
# Out:
# Cluster 0 characteristics:
# Income              63839.193483
# Kidhome                 0.067210
# Teenhome                0.800407
# Recency                48.010183
# MntWines              571.494908
# MntFruits              25.334012
# MntMeatProducts       175.661914
# MntFishProducts        33.492872
# MntSweetProducts       25.953157
# MntGoldProds           68.478615
# MntTotal              831.936864
# Name: 0, dtype: float64
# Number of customers: 491
# This cluster has a higher than average income.
# This cluster spends more than the average.
#
# Cluster 1 characteristics:
# Income              75466.191617
# Kidhome                 0.063872
# Teenhome                0.187625
# Recency                50.381238
# MntWines              604.748503
# MntFruits              76.009980
# MntMeatProducts       474.455090
# MntFishProducts       110.912176
# MntSweetProducts       78.672655
# MntGoldProds           80.081836
# MntTotal             1344.798403
# ...
